# %% [markdown]
# <a href="https://colab.research.google.com/github/Nicordaro/Project_MLDL/blob/master/point3/L1_sui_fc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Cloning files needed*

# %%
import os
# Clone github repository with data
# if os.path.isdir('./Project_MLDL'):
# !rm -rf Project_MLDL
if not os.path.isdir('./CIFAR100_tError'):
  # !git clone https://github.com/Nicordaro/Project_MLDL
# Out:
# Cloning into 'Project_MLDL'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 460 (delta 15), reused 0 (delta 0), pack-reused 429
# Receiving objects: 100% (460/460), 1.16 MiB | 2.67 MiB/s, done.
# Resolving deltas: 100% (253/253), done.

# %% [markdown]
# **Imports**
#
# ---

# %%
import logging
import matplotlib.pyplot as plt
import numpy as np
import random
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import time
import gc



from PIL import Image
from Project_MLDL.CIFAR100_tError import CIFAR100_tError
from Project_MLDL.model_finetuning import ResNet18
from torch.utils.data import Subset, DataLoader
from torch.backends import cudnn
from torchvision import transforms
from torchvision.models import resnet18
from torchvision.models import resnet34
from tqdm import tqdm

# Garbage collector
gc.enable()

# %% [markdown]
# **Arguments**
#
# ---

# %%
DEVICE = 'cuda' # 'cuda' or 'cpu'

# Init at 10 because first train is on 10 classes
NUM_CLASSES = 10

# Used for the pseudorandom shuffle of the split
SEED = 12

BATCH_SIZE = 128     # Higher batch sizes allows for larger learning rates. An empirical heuristic suggests that, when changing
                     # the batch size, learning rate should change by the same factor to have comparable results

LR = 2         # The initial Learning Rate
MOMENTUM = 0.9       # Hyperparameter for SGD, keep this at 0.9 when using SGD
WEIGHT_DECAY = 1e-5  # Regularization, you can keep this at the default

NUM_EPOCHS = 70     # Total number of training epochs (iterations over dataset)
MILESTONES = [48, 62]  # How many epochs before decreasing learning rate (if using a step-down policy)
GAMMA = 0.2          # Multiplicative factor for learning rate step-down

LOG_FREQUENCY = 50

# %% [markdown]
# **Transformations definition**
#
# ---

# %%
# Define transforms for training phase
train_transform = transforms.Compose([transforms.RandomHorizontalFlip(), # Randomly flip the image with probability of 0.5
                                      transforms.Pad(4), # Add padding
                                      transforms.RandomCrop(32),# Crops a random squares of the image
                                      transforms.ToTensor(), # Turn PIL Image to torch.Tensor
                                      transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)) 
])
# Define transforms for the evaluation phase
eval_transform = transforms.Compose([
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))                                 
])
eval_transform = transforms.Compose([
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))                                 
])
exemplar_transform = transforms.Compose([transforms.RandomHorizontalFlip(), # Randomly flip the image with probability of 0.5
                                      transforms.Pad(4), # Add padding
                                      transforms.RandomCrop(32),# Crops a random squares of the image
                                      transforms.ToTensor() # Turn PIL Image to torch.Tensor
])

# %% [markdown]
# *New label function*

# %%
DATA_DIR = './CIFAR100'

lbls = [i for i in range(0,100)]  #Array of classes integer-encoded (?)
random.seed(SEED)
random.shuffle(lbls)

def make_data_labels(lbls):     #After shuffle, take first 10 classes, and remove the first 10 from the list passed as argument
    new_labels=[]
    for el in lbls[:10]:
        new_labels.append(el)
    lbls = lbls[10:]

    return lbls, new_labels

# %%
from torch.utils.data import Dataset
"""
Take 2 datasets and combine them
"""
class joint_dataset(Dataset):
    
    def __init__(self,d1,d2):
        self.l1 = len(d1)
        self.l2 = len(d2)
        self.d1 = d1
        self.d2 = d2
    def __getitem__(self,index):
        if index>=self.l1:
            image,label = self.d2[index-self.l1]
            image = exemplar_transform(image) # Apply transformations to images
            return image,label
        else:
            image,label = self.d1[index]
            return image,label
    def __len__(self):
        return (self.l1 + self.l2)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import copy
from torch.autograd import Variable

class iCaRL(nn.Module):
  def __init__(self):
    super(iCaRL, self).__init__()

    # CNN with 100 neurons in the last layer (Features Extractor + FC)
    self.net = ResNet18()
    self.net.linear = nn.Linear(512, 100)
    
    # Classification and Distillation losses
    self.cls_loss = nn.BCEWithLogitsLoss(reduction='none')
    self.dist_loss = nn.L1Loss(reduction='none')
    
    self.exemplar_sets=[] # List of exemplar sets, one for each class
    self.exemplars_means=[] # List of exemplar means, one for each exemplar set

  def classify(self, x):

    torch.no_grad()
    torch.cuda.empty_cache()
    
    feature_extractor = self.net.to(DEVICE)
    feature_extractor.train(False)

    size = x.size(0) # Take batch size

    means = torch.cat(self.exemplar_means,dim=0) # Tensor of means (num_classes,num_features)
    means = torch.stack([means]*size) # (batch_size,num_classes,num_features)
    means = means.transpose(1, 2) # (batch_size,num_features,num_classes)
    
    feature_x = feature_extractor.extract_features(x) # (batch_size, num_features)
    
    # Normalize features
    features_normalized = []
    for x in feature_x:
        x.data = x.data / x.data.norm()
        features_normalized.append(x)   
    feature_x = torch.stack(features_normalized,dim=0)

    feature_x = feature_x.unsqueeze(2) # (batch_size, feature_size, 1)
    feature_x = feature_x.expand_as(means) # (batch_size, feature_size, n_classes)

    # find the nearest prototype
    means = means.to(DEVICE)
    labels = torch.argmin((feature_x - means).pow(2).sum(1),dim=1)
    
    #clean memory
    del feature_x
    del means
    del x
    del feature_extractor
    torch.no_grad()
    torch.cuda.empty_cache()
    gc.collect()
    
    return labels

  def compute_means(self,X):
    torch.no_grad()  
    torch.cuda.empty_cache()

    # Given the exemplar sets, compute the means

    exemplar_means = []
    feature_extractor = self.net.to(DEVICE)
    feature_extractor.train(False)

    with torch.no_grad():
      # Don't take the last 10 classes
      for i,Py in enumerate(self.exemplar_sets):
        if i>=(len(self.exemplar_sets)-10):
          break
        features=[]
        for p in Py:
          p = p.to(DEVICE)
          feature = feature_extractor.extract_features(p)
          features.append(feature)
          #Clean Memory
          del p
          del feature
          torch.no_grad()
          torch.cuda.empty_cache()

        features = torch.stack(features) # (num_exemplars,num_features)
        mu_y = features.mean(0) 
        mu_y.data = mu_y.data / mu_y.data.norm() # Normalize
        mu_y = mu_y.to('cpu')
        exemplar_means.append(mu_y)
        del features
        del mu_y
        torch.no_grad()  
        torch.cuda.empty_cache()

    #Compute the mean for the last 10 using the dataset
    with torch.no_grad():
      for x in X:
        features=[]
        for element in x:
          image,label = element
          image = image.unsqueeze(dim=0).to(DEVICE)
          feature = feature_extractor.extract_features(image)
          features.append(feature)
          #Clean Memory
          del image
          del feature
          torch.no_grad()
          torch.cuda.empty_cache()

        features = torch.stack(features) # (num_exemplars,num_features)
        mu_y = features.mean(0) 
        mu_y.data = mu_y.data / mu_y.data.norm() # Normalize
        mu_y = mu_y.to('cpu')
        exemplar_means.append(mu_y)
        del features
        del mu_y
        torch.no_grad()  
        torch.cuda.empty_cache()

    self.exemplar_means = exemplar_means

    #Clean Memory
    del exemplar_means
    del feature_extractor
    torch.no_grad()
    torch.cuda.empty_cache()


  def reduce_exemplar_sets(self,m):
    for y, P_y in enumerate(self.exemplar_sets):
      m = int(m)
      self.exemplar_sets[y] = P_y[:m] # keep only the first m exemplars
  
  def construct_exemplar_set(self,X,m):
    
    # X dataset containing all elements of class y

    torch.no_grad()
    torch.cuda.empty_cache()
    gc.collect()

    feature_extractor = self.net.to(DEVICE)
    feature_extractor.train(False)
    loader = DataLoader(X,batch_size=BATCH_SIZE,shuffle=True,drop_last=False,num_workers = 4) # create dataloader

    features = []
    
    for images,labels in loader:
      images = images.to(DEVICE)
      labels = labels.to(DEVICE)
      feature = feature_extractor.extract_features(images)
      features.append(feature)
      del images
      del labels
      del feature
        
    features_stacked = torch.cat(features) # (num_elements,num_features)
    mean = features_stacked.mean(0) #(num_features)
    mean = torch.stack([mean]*features_stacked.size()[0])  # (num_elements,num_features)
    torch.cuda.empty_cache()
    P = [] # exemplar set
    extracted_features = []

    summa = torch.zeros(1,features_stacked.size()[1]).to(DEVICE) #(1,num_features)
    
    for k in range(1,int(m+1)):
      s = torch.cat([summa]*features_stacked.size()[0]) #(num_elements,num_features)
      index = torch.argmin((mean-(1/k)*(features_stacked+s)).pow(2).sum(1),dim=0)
      features_stacked[index] = features_stacked[index]*100
      pk = X[index.item()][0].unsqueeze(dim=0) # take the image, leave the label
      P.append(pk)
      phipk =  feature_extractor.extract_features(pk.to(DEVICE))
      summa = summa + phipk # update sum of features
      del pk 
   
    #Clear Memory
    del summa
    del features
    del features_stacked
    del mean
    del s
    del feature_extractor
    del loader
    torch.cuda.empty_cache()
    self.exemplar_sets.append(P)
    

  def update_representation(self,X): 
    
    trans = transforms.ToPILImage()
    #Take exemplars
    exemplars_dataset = []
    for i in range(0,len(self.exemplar_sets)):
        for exemplar in self.exemplar_sets[i]:
            exemplar = trans(exemplar.squeeze()).convert("RGB")
            exemplars_dataset.append((exemplar,i)) #append the image in the list with label = index

    D = joint_dataset(X,exemplars_dataset) # Build the dataset 
   
    net = self.net

    #optimizer
    optimizer = optim.SGD(net.parameters(), lr=2, weight_decay=1e-5, momentum=0.9)

    # Scheduler
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=MILESTONES, gamma=GAMMA, last_epoch=-1)

    criterion = self.cls_loss
    criterion2 = self.dist_loss

    cudnn.benchmark # Calling this optimizes runtime

    current_step = 0
    net = net.to(DEVICE)
    
    # Create Dataloader 
    loader = DataLoader(D, batch_size=BATCH_SIZE, shuffle=True, num_workers=4, drop_last=True)
    
    if len(self.exemplar_sets)>1:
        old = copy.deepcopy(net) #copy network before training
    
    #Training
    for epoch in range(NUM_EPOCHS):
      print('Starting epoch {}/{}, LR = {}'.format(epoch+1, NUM_EPOCHS, scheduler.get_last_lr()))

        # Iterate over the dataset
      for images, labels in loader:
          # Bring data over the device of choice
          images = images.to(DEVICE)
          labels = labels.to(DEVICE)
          net.train()
        
          optimizer.zero_grad() # Zero-ing the gradients

          # Forward pass to the network
          outputs = net(images)

          # One hot encoding labels for binary cross-entropy loss
          labels_onehot = nn.functional.one_hot(labels,100).type_as(outputs)

          # Compute Loss 
          if len(self.exemplar_sets)==0:
            loss = criterion(outputs, labels_onehot).mean()
          else:
            out = outputs[:,len(self.exemplar_sets):]
            labels_onehot = labels_onehot[:,len(self.exemplar_sets):]
            loss1 = criterion(out,labels_onehot)

            out = outputs[:,:len(self.exemplar_sets)]
            out_old = Variable(old(images)[:,:len(self.exemplar_sets)],requires_grad=False)
  
            loss2 = criterion2(out,out_old)

            loss = torch.cat([loss1,loss2],dim=1).mean()

          if current_step % LOG_FREQUENCY == 0:
              print('Step {}, Loss {}'.format(current_step, loss.item()))

          loss.backward()  # backward pass: computes gradients
          optimizer.step() # update weights based on accumulated gradients
          current_step += 1
        
      scheduler.step()
    
    # Save the trained network and update features extractor
    self.net = copy.deepcopy(net)
    del net
    torch.no_grad()
    torch.cuda.empty_cache()

# %%
net = iCaRL()
K = 2000 # Memory Size
t = 0 # Number of classes
accuracies = [] # List of results 
test_dataset = CIFAR100_tError(DATA_DIR, train=False, transform=eval_transform, download=True)

for i in range(0,10): # batches of 10
  print(f"processing batch {i+1}")
  #Create Datasets
  train_datasets = []
  train_dataset_big = CIFAR100_tError(DATA_DIR, train=True, transform=train_transform, download=True)
  lbls, new_labels = make_data_labels(lbls) # take 10 new classes
  for label in new_labels:
    train_dataset = CIFAR100_tError(DATA_DIR, train=True, transform=eval_transform, download=True)
    train_dataset.increment([label],[t])
    test_dataset.increment([label],[t])
    train_dataset_big.increment([label],[t])
    train_datasets.append(train_dataset) # List of training examples in per class sets
    t += 1
  test_dataloader = DataLoader(test_dataset,batch_size=BATCH_SIZE,shuffle=True,num_workers=4)
  net.update_representation(train_dataset_big)
  m = K/t #numbers of exemplars per class
  net.reduce_exemplar_sets(m)
  for X in train_datasets:
    print("Construct Exemplar")
    net.construct_exemplar_set(X,m) #new exemplar sets
    torch.no_grad()
    torch.cuda.empty_cache()
    gc.collect()
  # Test on Test set
  running_corrects = 0
  print("Computing Means")
  net.compute_means(train_datasets)
  print("classifing")
  for images,labels in test_dataloader:
    images = images.to(DEVICE)
    labels = labels.to(DEVICE)
    preds = net.classify(images)
    running_corrects += torch.sum(preds == labels.data).data.item()
    accuracy = running_corrects / float(len(test_dataset))
    del images
    del labels
    del preds
    torch.no_grad()
    torch.cuda.empty_cache()
    gc.collect()
  accuracies.append(accuracy)
  print(f"Test Accuracy: {accuracy}")
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./CIFAR100/cifar-100-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./CIFAR100/cifar-100-python.tar.gz to ./CIFAR100
# processing batch 1
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Starting epoch 1/70, LR = [2]
# Step 0, Loss 0.733056366443634
# Starting epoch 2/70, LR = [2]
# Step 50, Loss 0.022089166566729546
# Starting epoch 3/70, LR = [2]
# Step 100, Loss 0.022402754053473473
# Starting epoch 4/70, LR = [2]
# Step 150, Loss 0.018743528053164482
# Starting epoch 5/70, LR = [2]
# Starting epoch 6/70, LR = [2]
# Step 200, Loss 0.020770374685525894
# Starting epoch 7/70, LR = [2]
# Step 250, Loss 0.01712290197610855
# Starting epoch 8/70, LR = [2]
# Step 300, Loss 0.020610501989722252
# Starting epoch 9/70, LR = [2]
# Step 350, Loss 0.014115986414253712
# Starting epoch 10/70, LR = [2]
# Starting epoch 11/70, LR = [2]
# Step 400, Loss 0.015188188292086124
# Starting epoch 12/70, LR = [2]
# Step 450, Loss 0.014455563388764858
# Starting epoch 13/70, LR = [2]
# Step 500, Loss 0.012647077441215515
# Starting epoch 14/70, LR = [2]
# Starting epoch 15/70, LR = [2]
# Step 550, Loss 0.01057171169668436
# Starting epoch 16/70, LR = [2]
# Step 600, Loss 0.010369673371315002
# Starting epoch 17/70, LR = [2]
# Step 650, Loss 0.009426780976355076
# Starting epoch 18/70, LR = [2]
# Step 700, Loss 0.009248679503798485
# Starting epoch 19/70, LR = [2]
# Starting epoch 20/70, LR = [2]
# Step 750, Loss 0.008226878009736538
# Starting epoch 21/70, LR = [2]
# Step 800, Loss 0.007504695560783148
# Starting epoch 22/70, LR = [2]
# Step 850, Loss 0.009600520133972168
# Starting epoch 23/70, LR = [2]
# Starting epoch 24/70, LR = [2]
# Step 900, Loss 0.0055422247387468815
# Starting epoch 25/70, LR = [2]
# Step 950, Loss 0.006497095804661512
# Starting epoch 26/70, LR = [2]
# Step 1000, Loss 0.00783750880509615
# Starting epoch 27/70, LR = [2]
# Step 1050, Loss 0.006959978025406599
# Starting epoch 28/70, LR = [2]
# Starting epoch 29/70, LR = [2]
# Step 1100, Loss 0.005320210475474596
# Starting epoch 30/70, LR = [2]
# Step 1150, Loss 0.005786938592791557
# Starting epoch 31/70, LR = [2]
# Step 1200, Loss 0.007795176934450865
# Starting epoch 32/70, LR = [2]
# Starting epoch 33/70, LR = [2]
# Step 1250, Loss 0.0071276770904660225
# Starting epoch 34/70, LR = [2]
# Step 1300, Loss 0.004697900731116533
# Starting epoch 35/70, LR = [2]
# Step 1350, Loss 0.003648071549832821
# Starting epoch 36/70, LR = [2]
# Step 1400, Loss 0.004399562254548073
# Starting epoch 37/70, LR = [2]
# Starting epoch 38/70, LR = [2]
# Step 1450, Loss 0.007214555516839027
# Starting epoch 39/70, LR = [2]
# Step 1500, Loss 0.003747053910046816
# Starting epoch 40/70, LR = [2]
# Step 1550, Loss 0.004765571095049381
# Starting epoch 41/70, LR = [2]
# Starting epoch 42/70, LR = [2]
# Step 1600, Loss 0.002373042982071638
# Starting epoch 43/70, LR = [2]
# Step 1650, Loss 0.004219689406454563
# Starting epoch 44/70, LR = [2]
# Step 1700, Loss 0.0024988437071442604
# Starting epoch 45/70, LR = [2]
# Step 1750, Loss 0.0033444389700889587
# Starting epoch 46/70, LR = [2]
# Starting epoch 47/70, LR = [2]
# Step 1800, Loss 0.0036769115831702948
# Starting epoch 48/70, LR = [2]
# Step 1850, Loss 0.0027488465420901775
# Starting epoch 49/70, LR = [0.4]
# Step 1900, Loss 0.0007671480998396873
# Starting epoch 50/70, LR = [0.4]
# Starting epoch 51/70, LR = [0.4]
# Step 1950, Loss 0.0006558885797858238
# Starting epoch 52/70, LR = [0.4]
# Step 2000, Loss 0.0003969756362494081
# Starting epoch 53/70, LR = [0.4]
# Step 2050, Loss 0.001181229017674923
# Starting epoch 54/70, LR = [0.4]
# Step 2100, Loss 0.0008701390470378101
# Starting epoch 55/70, LR = [0.4]
# Starting epoch 56/70, LR = [0.4]
# Step 2150, Loss 0.0005534387892112136
# Starting epoch 57/70, LR = [0.4]
# Step 2200, Loss 0.0002825816336553544
# Starting epoch 58/70, LR = [0.4]
# Step 2250, Loss 0.0003173547447659075
# Starting epoch 59/70, LR = [0.4]
# Step 2300, Loss 0.0003196990001015365
# Starting epoch 60/70, LR = [0.4]
# Starting epoch 61/70, LR = [0.4]
# Step 2350, Loss 0.0004299166612327099
# Starting epoch 62/70, LR = [0.4]
# Step 2400, Loss 0.00014677333820145577
# Starting epoch 63/70, LR = [0.08000000000000002]
# Step 2450, Loss 0.00032277105492539704
# Starting epoch 64/70, LR = [0.08000000000000002]
# Starting epoch 65/70, LR = [0.08000000000000002]
# Step 2500, Loss 0.0005364283570088446
# Starting epoch 66/70, LR = [0.08000000000000002]
# Step 2550, Loss 0.00020849943393841386
# Starting epoch 67/70, LR = [0.08000000000000002]
# Step 2600, Loss 0.0001848623505793512
# Starting epoch 68/70, LR = [0.08000000000000002]
# Step 2650, Loss 0.00020761889754794538
# Starting epoch 69/70, LR = [0.08000000000000002]
# Starting epoch 70/70, LR = [0.08000000000000002]
# Step 2700, Loss 0.00027533716638572514
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Computing Means
# classifing
# Test Accuracy: 0.842
# processing batch 2
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Starting epoch 1/70, LR = [2]
# Step 0, Loss 0.3702333867549896
# Step 50, Loss 0.2686616778373718
# Starting epoch 2/70, LR = [2]
# Step 100, Loss 0.23711861670017242
# Starting epoch 3/70, LR = [2]
# Step 150, Loss 0.20709793269634247
# Starting epoch 4/70, LR = [2]
# Step 200, Loss 0.19836081564426422
# Starting epoch 5/70, LR = [2]
# Step 250, Loss 0.17558826506137848
# Starting epoch 6/70, LR = [2]
# Step 300, Loss 0.1722494512796402
# Starting epoch 7/70, LR = [2]
# Step 350, Loss 0.16099488735198975
# Starting epoch 8/70, LR = [2]
# Step 400, Loss 0.16806302964687347
# Starting epoch 9/70, LR = [2]
# Step 450, Loss 0.14569030702114105
# Starting epoch 10/70, LR = [2]
# Step 500, Loss 0.15721671283245087
# Starting epoch 11/70, LR = [2]
# Step 550, Loss 0.15158534049987793
# Starting epoch 12/70, LR = [2]
# Step 600, Loss 0.1580820083618164
# Starting epoch 13/70, LR = [2]
# Step 650, Loss 0.1509627252817154
# Step 700, Loss 0.1337386816740036
# Starting epoch 14/70, LR = [2]
# Step 750, Loss 0.14408206939697266
# Starting epoch 15/70, LR = [2]
# Step 800, Loss 0.1521935760974884
# Starting epoch 16/70, LR = [2]
# Step 850, Loss 0.1315942108631134
# Starting epoch 17/70, LR = [2]
# Step 900, Loss 0.13078078627586365
# Starting epoch 18/70, LR = [2]
# Step 950, Loss 0.13939931988716125
# Starting epoch 19/70, LR = [2]
# Step 1000, Loss 0.13176825642585754
# Starting epoch 20/70, LR = [2]
# Step 1050, Loss 0.11429578810930252
# Starting epoch 21/70, LR = [2]
# Step 1100, Loss 0.11569619178771973
# Starting epoch 22/70, LR = [2]
# Step 1150, Loss 0.12191835045814514
# Starting epoch 23/70, LR = [2]
# Step 1200, Loss 0.11159822344779968
# Starting epoch 24/70, LR = [2]
# Step 1250, Loss 0.1309148371219635
# Starting epoch 25/70, LR = [2]
# Step 1300, Loss 0.12971250712871552
# Starting epoch 26/70, LR = [2]
# Step 1350, Loss 0.11317960172891617
# Step 1400, Loss 0.12127380073070526
# Starting epoch 27/70, LR = [2]
# Step 1450, Loss 0.12441106885671616
# Starting epoch 28/70, LR = [2]
# Step 1500, Loss 0.11208310723304749
# Starting epoch 29/70, LR = [2]
# Step 1550, Loss 0.13498149812221527
# Starting epoch 30/70, LR = [2]
# Step 1600, Loss 0.10440357774496078
# Starting epoch 31/70, LR = [2]
# Step 1650, Loss 0.11564112454652786
# Starting epoch 32/70, LR = [2]
# Step 1700, Loss 0.10636607557535172
# Starting epoch 33/70, LR = [2]
# Step 1750, Loss 0.10259589552879333
# Starting epoch 34/70, LR = [2]
# Step 1800, Loss 0.10832250118255615
# Starting epoch 35/70, LR = [2]
# Step 1850, Loss 0.10803639143705368
# Starting epoch 36/70, LR = [2]
# Step 1900, Loss 0.1256973296403885
# Starting epoch 37/70, LR = [2]
# Step 1950, Loss 0.1074267104268074
# Starting epoch 38/70, LR = [2]
# Step 2000, Loss 0.11317140609025955
# Step 2050, Loss 0.11886298656463623
# Starting epoch 39/70, LR = [2]
# Step 2100, Loss 0.10485248267650604
# Starting epoch 40/70, LR = [2]
# Step 2150, Loss 0.12719452381134033
# Starting epoch 41/70, LR = [2]
# Step 2200, Loss 0.10362918674945831
# Starting epoch 42/70, LR = [2]
# Step 2250, Loss 0.09694366157054901
# Starting epoch 43/70, LR = [2]
# Step 2300, Loss 0.10251426696777344
# Starting epoch 44/70, LR = [2]
# Step 2350, Loss 0.11206792294979095
# Starting epoch 45/70, LR = [2]
# Step 2400, Loss 0.10678872466087341
# Starting epoch 46/70, LR = [2]
# Step 2450, Loss 0.10256049782037735
# Starting epoch 47/70, LR = [2]
# Step 2500, Loss 0.11004006117582321
# Starting epoch 48/70, LR = [2]
# Step 2550, Loss 0.1117396131157875
# Starting epoch 49/70, LR = [0.4]
# Step 2600, Loss 0.09281452745199203
# Starting epoch 50/70, LR = [0.4]
# Step 2650, Loss 0.0854489877820015
# Starting epoch 51/70, LR = [0.4]
# Step 2700, Loss 0.0687393769621849
# Step 2750, Loss 0.0711006224155426
# Starting epoch 52/70, LR = [0.4]
# Step 2800, Loss 0.07983200252056122
# Starting epoch 53/70, LR = [0.4]
# Step 2850, Loss 0.06693130731582642
# Starting epoch 54/70, LR = [0.4]
# Step 2900, Loss 0.07100624591112137
# Starting epoch 55/70, LR = [0.4]
# Step 2950, Loss 0.06728401780128479
# Starting epoch 56/70, LR = [0.4]
# Step 3000, Loss 0.06933080404996872
# Starting epoch 57/70, LR = [0.4]
# Step 3050, Loss 0.07917124778032303
# Starting epoch 58/70, LR = [0.4]
# Step 3100, Loss 0.06892494857311249
# Starting epoch 59/70, LR = [0.4]
# Step 3150, Loss 0.07146786898374557
# Starting epoch 60/70, LR = [0.4]
# Step 3200, Loss 0.07949423789978027
# Starting epoch 61/70, LR = [0.4]
# Step 3250, Loss 0.06500925123691559
# Starting epoch 62/70, LR = [0.4]
# Step 3300, Loss 0.07330819219350815
# Starting epoch 63/70, LR = [0.08000000000000002]
# Step 3350, Loss 0.06993638724088669
# Step 3400, Loss 0.058725059032440186
# Starting epoch 64/70, LR = [0.08000000000000002]
# Step 3450, Loss 0.06340896338224411
# Starting epoch 65/70, LR = [0.08000000000000002]
# Step 3500, Loss 0.06167848780751228
# Starting epoch 66/70, LR = [0.08000000000000002]
# Step 3550, Loss 0.05976665019989014
# Starting epoch 67/70, LR = [0.08000000000000002]
# Step 3600, Loss 0.07283367216587067
# Starting epoch 68/70, LR = [0.08000000000000002]
# Step 3650, Loss 0.05882180854678154
# Starting epoch 69/70, LR = [0.08000000000000002]
# Step 3700, Loss 0.06602809578180313
# Starting epoch 70/70, LR = [0.08000000000000002]
# Step 3750, Loss 0.07775954902172089
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Computing Means
# classifing
# Test Accuracy: 0.688
# processing batch 3
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Starting epoch 1/70, LR = [2]
# Step 0, Loss 0.1655614674091339
# Step 50, Loss 0.19133435189723969
# Starting epoch 2/70, LR = [2]
# Step 100, Loss 0.19819337129592896
# Starting epoch 3/70, LR = [2]
# Step 150, Loss 0.19065256416797638
# Starting epoch 4/70, LR = [2]
# Step 200, Loss 0.17682971060276031
# Starting epoch 5/70, LR = [2]
# Step 250, Loss 0.15913352370262146
# Starting epoch 6/70, LR = [2]
# Step 300, Loss 0.14654885232448578
# Starting epoch 7/70, LR = [2]
# Step 350, Loss 0.15898248553276062
# Starting epoch 8/70, LR = [2]
# Step 400, Loss 0.14938166737556458
# Starting epoch 9/70, LR = [2]
# Step 450, Loss 0.1595107614994049
# Starting epoch 10/70, LR = [2]
# Step 500, Loss 0.1470344066619873
# Starting epoch 11/70, LR = [2]
# Step 550, Loss 0.15590983629226685
# Starting epoch 12/70, LR = [2]
# Step 600, Loss 0.15073566138744354
# Starting epoch 13/70, LR = [2]
# Step 650, Loss 0.14932261407375336
# Step 700, Loss 0.1575256586074829
# Starting epoch 14/70, LR = [2]
# Step 750, Loss 0.15462128818035126
# Starting epoch 15/70, LR = [2]
# Step 800, Loss 0.15829499065876007
# Starting epoch 16/70, LR = [2]
# Step 850, Loss 0.15192611515522003
# Starting epoch 17/70, LR = [2]
# Step 900, Loss 0.14383506774902344
# Starting epoch 18/70, LR = [2]
# Step 950, Loss 0.14441058039665222
# Starting epoch 19/70, LR = [2]
# Step 1000, Loss 0.1393388956785202
# Starting epoch 20/70, LR = [2]
# Step 1050, Loss 0.13120126724243164
# Starting epoch 21/70, LR = [2]
# Step 1100, Loss 0.12460657954216003
# Starting epoch 22/70, LR = [2]
# Step 1150, Loss 0.1396482288837433
# Starting epoch 23/70, LR = [2]
# Step 1200, Loss 0.16161681711673737
# Starting epoch 24/70, LR = [2]
# Step 1250, Loss 0.1334785670042038
# Starting epoch 25/70, LR = [2]
# Step 1300, Loss 0.13714483380317688
# Starting epoch 26/70, LR = [2]
# Step 1350, Loss 0.12158771604299545
# Step 1400, Loss 0.12744539976119995
# Starting epoch 27/70, LR = [2]
# Step 1450, Loss 0.140513613820076
# Starting epoch 28/70, LR = [2]
# Step 1500, Loss 0.13345108926296234
# Starting epoch 29/70, LR = [2]
# Step 1550, Loss 0.14165164530277252
# Starting epoch 30/70, LR = [2]
# Step 1600, Loss 0.1279578059911728
# Starting epoch 31/70, LR = [2]
# Step 1650, Loss 0.13929663598537445
# Starting epoch 32/70, LR = [2]
# Step 1700, Loss 0.15196825563907623
# Starting epoch 33/70, LR = [2]
# Step 1750, Loss 0.12030970305204391
# Starting epoch 34/70, LR = [2]
# Step 1800, Loss 0.13499565422534943
# Starting epoch 35/70, LR = [2]
# Step 1850, Loss 0.12649555504322052
# Starting epoch 36/70, LR = [2]
# Step 1900, Loss 0.14452201128005981
# Starting epoch 37/70, LR = [2]
# Step 1950, Loss 0.1281517595052719
# Starting epoch 38/70, LR = [2]
# Step 2000, Loss 0.12527766823768616
# Step 2050, Loss 0.12909480929374695
# Starting epoch 39/70, LR = [2]
# Step 2100, Loss 0.1326667219400406
# Starting epoch 40/70, LR = [2]
# Step 2150, Loss 0.12916432321071625
# Starting epoch 41/70, LR = [2]
# Step 2200, Loss 0.12023641169071198
# Starting epoch 42/70, LR = [2]
# Step 2250, Loss 0.12665891647338867
# Starting epoch 43/70, LR = [2]
# Step 2300, Loss 0.13069775700569153
# Starting epoch 44/70, LR = [2]
# Step 2350, Loss 0.12837357819080353
# Starting epoch 45/70, LR = [2]
# Step 2400, Loss 0.13236390054225922
# Starting epoch 46/70, LR = [2]
# Step 2450, Loss 0.14307521283626556
# Starting epoch 47/70, LR = [2]
# Step 2500, Loss 0.12033320218324661
# Starting epoch 48/70, LR = [2]
# Step 2550, Loss 0.126636803150177
# Starting epoch 49/70, LR = [0.4]
# Step 2600, Loss 0.1029098778963089
# Starting epoch 50/70, LR = [0.4]
# Step 2650, Loss 0.09184150397777557
# Starting epoch 51/70, LR = [0.4]
# Step 2700, Loss 0.08429807424545288
# Step 2750, Loss 0.09766944497823715
# Starting epoch 52/70, LR = [0.4]
# Step 2800, Loss 0.09222669154405594
# Starting epoch 53/70, LR = [0.4]
# Step 2850, Loss 0.09049699455499649
# Starting epoch 54/70, LR = [0.4]
# Step 2900, Loss 0.08974487334489822
# Starting epoch 55/70, LR = [0.4]
# Step 2950, Loss 0.09365323930978775
# Starting epoch 56/70, LR = [0.4]
# Step 3000, Loss 0.08417817950248718
# Starting epoch 57/70, LR = [0.4]
# Step 3050, Loss 0.08876599371433258
# Starting epoch 58/70, LR = [0.4]
# Step 3100, Loss 0.09357060492038727
# Starting epoch 59/70, LR = [0.4]
# Step 3150, Loss 0.07997820526361465
# Starting epoch 60/70, LR = [0.4]
# Step 3200, Loss 0.10720525681972504
# Starting epoch 61/70, LR = [0.4]
# Step 3250, Loss 0.08740010112524033
# Starting epoch 62/70, LR = [0.4]
# Step 3300, Loss 0.08830192685127258
# Starting epoch 63/70, LR = [0.08000000000000002]
# Step 3350, Loss 0.08852053433656693
# Step 3400, Loss 0.0695912316441536
# Starting epoch 64/70, LR = [0.08000000000000002]
# Step 3450, Loss 0.07326235622167587
# Starting epoch 65/70, LR = [0.08000000000000002]
# Step 3500, Loss 0.08050502836704254
# Starting epoch 66/70, LR = [0.08000000000000002]
# Step 3550, Loss 0.08710861951112747
# Starting epoch 67/70, LR = [0.08000000000000002]
# Step 3600, Loss 0.07805805653333664
# Starting epoch 68/70, LR = [0.08000000000000002]
# Step 3650, Loss 0.06356562674045563
# Starting epoch 69/70, LR = [0.08000000000000002]
# Step 3700, Loss 0.06355183571577072
# Starting epoch 70/70, LR = [0.08000000000000002]
# Step 3750, Loss 0.07283555716276169
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Computing Means
# classifing
# Test Accuracy: 0.57
# processing batch 4
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Starting epoch 1/70, LR = [2]
# Step 0, Loss 0.23700274527072906
# Step 50, Loss 0.17607885599136353
# Starting epoch 2/70, LR = [2]
# Step 100, Loss 0.19050990045070648
# Starting epoch 3/70, LR = [2]
# Step 150, Loss 0.1928102821111679
# Starting epoch 4/70, LR = [2]
# Step 200, Loss 0.1624000072479248
# Starting epoch 5/70, LR = [2]
# Step 250, Loss 0.17414623498916626
# Starting epoch 6/70, LR = [2]
# Step 300, Loss 0.16338393092155457
# Starting epoch 7/70, LR = [2]
# Step 350, Loss 0.18325160443782806
# Starting epoch 8/70, LR = [2]
# Step 400, Loss 0.16909731924533844
# Starting epoch 9/70, LR = [2]
# Step 450, Loss 0.1566183865070343
# Starting epoch 10/70, LR = [2]
# Step 500, Loss 0.18139302730560303
# Starting epoch 11/70, LR = [2]
# Step 550, Loss 0.15295924246311188
# Starting epoch 12/70, LR = [2]
# Step 600, Loss 0.16731590032577515
# Starting epoch 13/70, LR = [2]
# Step 650, Loss 0.1587039977312088
# Step 700, Loss 0.1697634905576706
# Starting epoch 14/70, LR = [2]
# Step 750, Loss 0.1547584980726242
# Starting epoch 15/70, LR = [2]
# Step 800, Loss 0.17034469544887543
# Starting epoch 16/70, LR = [2]
# Step 850, Loss 0.15268684923648834
# Starting epoch 17/70, LR = [2]
# Step 900, Loss 0.1607459932565689
# Starting epoch 18/70, LR = [2]
# Step 950, Loss 0.1500895470380783
# Starting epoch 19/70, LR = [2]
# Step 1000, Loss 0.16060692071914673
# Starting epoch 20/70, LR = [2]
# Step 1050, Loss 0.14765167236328125
# Starting epoch 21/70, LR = [2]
# Step 1100, Loss 0.17478400468826294
# Starting epoch 22/70, LR = [2]
# Step 1150, Loss 0.1687631905078888
# Starting epoch 23/70, LR = [2]
# Step 1200, Loss 0.15805740654468536
# Starting epoch 24/70, LR = [2]
# Step 1250, Loss 0.13155172765254974
# Starting epoch 25/70, LR = [2]
# Step 1300, Loss 0.18086828291416168
# Starting epoch 26/70, LR = [2]
# Step 1350, Loss 0.15877628326416016
# Step 1400, Loss 0.14258800446987152
# Starting epoch 27/70, LR = [2]
# Step 1450, Loss 0.13832974433898926
# Starting epoch 28/70, LR = [2]
# Step 1500, Loss 0.14537087082862854
# Starting epoch 29/70, LR = [2]
# Step 1550, Loss 0.137323796749115
# Starting epoch 30/70, LR = [2]
# Step 1600, Loss 0.15823599696159363
# Starting epoch 31/70, LR = [2]
# Step 1650, Loss 0.15007226169109344
# Starting epoch 32/70, LR = [2]
# Step 1700, Loss 0.12835519015789032
# Starting epoch 33/70, LR = [2]
# Step 1750, Loss 0.15509751439094543
# Starting epoch 34/70, LR = [2]
# Step 1800, Loss 0.14520105719566345
# Starting epoch 35/70, LR = [2]
# Step 1850, Loss 0.1530667245388031
# Starting epoch 36/70, LR = [2]
# Step 1900, Loss 0.1537078619003296
# Starting epoch 37/70, LR = [2]
# Step 1950, Loss 0.13452348113059998
# Starting epoch 38/70, LR = [2]
# Step 2000, Loss 0.14800648391246796
# Step 2050, Loss 0.16067036986351013
# Starting epoch 39/70, LR = [2]
# Step 2100, Loss 0.14135108888149261
# Starting epoch 40/70, LR = [2]
# Step 2150, Loss 0.14766456186771393
# Starting epoch 41/70, LR = [2]
# Step 2200, Loss 0.1616399735212326
# Starting epoch 42/70, LR = [2]
# Step 2250, Loss 0.1559750884771347
# Starting epoch 43/70, LR = [2]
# Step 2300, Loss 0.1444874107837677
# Starting epoch 44/70, LR = [2]
# Step 2350, Loss 0.15223756432533264
# Starting epoch 45/70, LR = [2]
# Step 2400, Loss 0.14459247887134552
# Starting epoch 46/70, LR = [2]
# Step 2450, Loss 0.16666190326213837
# Starting epoch 47/70, LR = [2]
# Step 2500, Loss 0.1353609263896942
# Starting epoch 48/70, LR = [2]
# Step 2550, Loss 0.16250677406787872
# Starting epoch 49/70, LR = [0.4]
# Step 2600, Loss 0.12489376962184906
# Starting epoch 50/70, LR = [0.4]
# Step 2650, Loss 0.1192292645573616
# Starting epoch 51/70, LR = [0.4]
# Step 2700, Loss 0.09937102347612381
# Step 2750, Loss 0.09734763205051422
# Starting epoch 52/70, LR = [0.4]
# Step 2800, Loss 0.09598227590322495
# Starting epoch 53/70, LR = [0.4]
# Step 2850, Loss 0.10589803755283356
# Starting epoch 54/70, LR = [0.4]
# Step 2900, Loss 0.10727626830339432
# Starting epoch 55/70, LR = [0.4]
# Step 2950, Loss 0.08754368871450424
# Starting epoch 56/70, LR = [0.4]
# Step 3000, Loss 0.10665517300367355
# Starting epoch 57/70, LR = [0.4]
# Step 3050, Loss 0.10263383388519287
# Starting epoch 58/70, LR = [0.4]
# Step 3100, Loss 0.09005891531705856
# Starting epoch 59/70, LR = [0.4]
# Step 3150, Loss 0.09043780714273453
# Starting epoch 60/70, LR = [0.4]
# Step 3200, Loss 0.1219753623008728
# Starting epoch 61/70, LR = [0.4]
# Step 3250, Loss 0.07463186979293823
# Starting epoch 62/70, LR = [0.4]
# Step 3300, Loss 0.10092175006866455
# Starting epoch 63/70, LR = [0.08000000000000002]
# Step 3350, Loss 0.09468170255422592
# Step 3400, Loss 0.08081910014152527
# Starting epoch 64/70, LR = [0.08000000000000002]
# Step 3450, Loss 0.08278604596853256
# Starting epoch 65/70, LR = [0.08000000000000002]
# Step 3500, Loss 0.08674874901771545
# Starting epoch 66/70, LR = [0.08000000000000002]
# Step 3550, Loss 0.09029975533485413
# Starting epoch 67/70, LR = [0.08000000000000002]
# Step 3600, Loss 0.0701882466673851
# Starting epoch 68/70, LR = [0.08000000000000002]
# Step 3650, Loss 0.07827313989400864
# Starting epoch 69/70, LR = [0.08000000000000002]
# Step 3700, Loss 0.08067816495895386
# Starting epoch 70/70, LR = [0.08000000000000002]
# Step 3750, Loss 0.08932261914014816
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Computing Means
# classifing
# Test Accuracy: 0.507
# processing batch 5
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Starting epoch 1/70, LR = [2]
# Step 0, Loss 0.3206501603126526
# Step 50, Loss 0.2100934386253357
# Starting epoch 2/70, LR = [2]
# Step 100, Loss 0.18672454357147217
# Starting epoch 3/70, LR = [2]
# Step 150, Loss 0.18046137690544128
# Starting epoch 4/70, LR = [2]
# Step 200, Loss 0.20681902766227722
# Starting epoch 5/70, LR = [2]
# Step 250, Loss 0.17034050822257996
# Starting epoch 6/70, LR = [2]
# Step 300, Loss 0.16675332188606262
# Starting epoch 7/70, LR = [2]
# Step 350, Loss 0.16222594678401947
# Starting epoch 8/70, LR = [2]
# Step 400, Loss 0.18277931213378906
# Starting epoch 9/70, LR = [2]
# Step 450, Loss 0.18581523001194
# Starting epoch 10/70, LR = [2]
# Step 500, Loss 0.16871052980422974
# Starting epoch 11/70, LR = [2]
# Step 550, Loss 0.15965208411216736
# Starting epoch 12/70, LR = [2]
# Step 600, Loss 0.19301564991474152
# Starting epoch 13/70, LR = [2]
# Step 650, Loss 0.1862020492553711
# Step 700, Loss 0.16496655344963074
# Starting epoch 14/70, LR = [2]
# Step 750, Loss 0.18661148846149445
# Starting epoch 15/70, LR = [2]
# Step 800, Loss 0.16484004259109497
# Starting epoch 16/70, LR = [2]
# Step 850, Loss 0.17287403345108032
# Starting epoch 17/70, LR = [2]
# Step 900, Loss 0.17582063376903534
# Starting epoch 18/70, LR = [2]
# Step 950, Loss 0.15642471611499786
# Starting epoch 19/70, LR = [2]
# Step 1000, Loss 0.1593373417854309
# Starting epoch 20/70, LR = [2]
# Step 1050, Loss 0.1688534915447235
# Starting epoch 21/70, LR = [2]
# Step 1100, Loss 0.1893899142742157
# Starting epoch 22/70, LR = [2]
# Step 1150, Loss 0.14249733090400696
# Starting epoch 23/70, LR = [2]
# Step 1200, Loss 0.17433924973011017
# Starting epoch 24/70, LR = [2]
# Step 1250, Loss 0.18385635316371918
# Starting epoch 25/70, LR = [2]
# Step 1300, Loss 0.16627483069896698
# Starting epoch 26/70, LR = [2]
# Step 1350, Loss 0.1609681248664856
# Step 1400, Loss 0.16928710043430328
# Starting epoch 27/70, LR = [2]
# Step 1450, Loss 0.14606612920761108
# Starting epoch 28/70, LR = [2]
# Step 1500, Loss 0.16158922016620636
# Starting epoch 29/70, LR = [2]
# Step 1550, Loss 0.1485484540462494
# Starting epoch 30/70, LR = [2]
# Step 1600, Loss 0.18836535513401031
# Starting epoch 31/70, LR = [2]
# Step 1650, Loss 0.1685238629579544
# Starting epoch 32/70, LR = [2]
# Step 1700, Loss 0.1655529886484146
# Starting epoch 33/70, LR = [2]
# Step 1750, Loss 0.15579192340373993
# Starting epoch 34/70, LR = [2]
# Step 1800, Loss 0.1745104342699051
# Starting epoch 35/70, LR = [2]
# Step 1850, Loss 0.14865215122699738
# Starting epoch 36/70, LR = [2]
# Step 1900, Loss 0.15901945531368256
# Starting epoch 37/70, LR = [2]
# Step 1950, Loss 0.15956811606884003
# Starting epoch 38/70, LR = [2]
# Step 2000, Loss 0.172715961933136
# Step 2050, Loss 0.16188475489616394
# Starting epoch 39/70, LR = [2]
# Step 2100, Loss 0.16348259150981903
# Starting epoch 40/70, LR = [2]
# Step 2150, Loss 0.1541968286037445
# Starting epoch 41/70, LR = [2]
# Step 2200, Loss 0.1718195676803589
# Starting epoch 42/70, LR = [2]
# Step 2250, Loss 0.16254931688308716
# Starting epoch 43/70, LR = [2]
# Step 2300, Loss 0.17417491972446442
# Starting epoch 44/70, LR = [2]
# Step 2350, Loss 0.15509316325187683
# Starting epoch 45/70, LR = [2]
# Step 2400, Loss 0.16101674735546112
# Starting epoch 46/70, LR = [2]
# Step 2450, Loss 0.15926949679851532
# Starting epoch 47/70, LR = [2]
# Step 2500, Loss 0.15566842257976532
# Starting epoch 48/70, LR = [2]
# Step 2550, Loss 0.14377769827842712
# Starting epoch 49/70, LR = [0.4]
# Step 2600, Loss 0.1313428282737732
# Starting epoch 50/70, LR = [0.4]
# Step 2650, Loss 0.11653367429971695
# Starting epoch 51/70, LR = [0.4]
# Step 2700, Loss 0.09753619134426117
# Step 2750, Loss 0.13214097917079926
# Starting epoch 52/70, LR = [0.4]
# Step 2800, Loss 0.11293456703424454
# Starting epoch 53/70, LR = [0.4]
# Step 2850, Loss 0.1061110869050026
# Starting epoch 54/70, LR = [0.4]
# Step 2900, Loss 0.09501198679208755
# Starting epoch 55/70, LR = [0.4]
# Step 2950, Loss 0.11129280179738998
# Starting epoch 56/70, LR = [0.4]
# Step 3000, Loss 0.15451680123806
# Starting epoch 57/70, LR = [0.4]
# Step 3050, Loss 0.09391812980175018
# Starting epoch 58/70, LR = [0.4]
# Step 3100, Loss 0.1077004224061966
# Starting epoch 59/70, LR = [0.4]
# Step 3150, Loss 0.0919395238161087
# Starting epoch 60/70, LR = [0.4]
# Step 3200, Loss 0.10507442057132721
# Starting epoch 61/70, LR = [0.4]
# Step 3250, Loss 0.09138292074203491
# Starting epoch 62/70, LR = [0.4]
# Step 3300, Loss 0.09454261511564255
# Starting epoch 63/70, LR = [0.08000000000000002]
# Step 3350, Loss 0.09821663796901703
# Step 3400, Loss 0.09419339895248413
# Starting epoch 64/70, LR = [0.08000000000000002]
# Step 3450, Loss 0.08846044540405273
# Starting epoch 65/70, LR = [0.08000000000000002]
# Step 3500, Loss 0.09032151848077774
# Starting epoch 66/70, LR = [0.08000000000000002]
# Step 3550, Loss 0.08167430758476257
# Starting epoch 67/70, LR = [0.08000000000000002]
# Step 3600, Loss 0.07445414364337921
# Starting epoch 68/70, LR = [0.08000000000000002]
# Step 3650, Loss 0.08237270265817642
# Starting epoch 69/70, LR = [0.08000000000000002]
# Step 3700, Loss 0.07728839665651321
# Starting epoch 70/70, LR = [0.08000000000000002]
# Step 3750, Loss 0.08426255732774734
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Computing Means
# classifing
# Test Accuracy: 0.4642
# processing batch 6
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Starting epoch 1/70, LR = [2]
# Step 0, Loss 0.4012567102909088
# Step 50, Loss 0.23942124843597412
# Starting epoch 2/70, LR = [2]
# Step 100, Loss 0.24286919832229614
# Starting epoch 3/70, LR = [2]
# Step 150, Loss 0.20344474911689758
# Starting epoch 4/70, LR = [2]
# Step 200, Loss 0.23556914925575256
# Starting epoch 5/70, LR = [2]
# Step 250, Loss 0.1886627972126007
# Starting epoch 6/70, LR = [2]
# Step 300, Loss 0.24029329419136047
# Starting epoch 7/70, LR = [2]
# Step 350, Loss 0.19204245507717133
# Starting epoch 8/70, LR = [2]
# Step 400, Loss 0.21452593803405762
# Starting epoch 9/70, LR = [2]
# Step 450, Loss 0.21525205671787262
# Starting epoch 10/70, LR = [2]
# Step 500, Loss 0.1877942681312561
# Starting epoch 11/70, LR = [2]
# Step 550, Loss 0.2152576744556427
# Starting epoch 12/70, LR = [2]
# Step 600, Loss 0.18667949736118317
# Starting epoch 13/70, LR = [2]
# Step 650, Loss 0.19557026028633118
# Step 700, Loss 0.2088266760110855
# Starting epoch 14/70, LR = [2]
# Step 750, Loss 0.18495704233646393
# Starting epoch 15/70, LR = [2]
# Step 800, Loss 0.20074480772018433
# Starting epoch 16/70, LR = [2]
# Step 850, Loss 0.16935241222381592
# Starting epoch 17/70, LR = [2]
# Step 900, Loss 0.25588586926460266
# Starting epoch 18/70, LR = [2]
# Step 950, Loss 0.20772992074489594
# Starting epoch 19/70, LR = [2]
# Step 1000, Loss 0.20047634840011597
# Starting epoch 20/70, LR = [2]
# Step 1050, Loss 0.2008204609155655
# Starting epoch 21/70, LR = [2]
# Step 1100, Loss 0.22903187572956085
# Starting epoch 22/70, LR = [2]
# Step 1150, Loss 0.2028186321258545
# Starting epoch 23/70, LR = [2]
# Step 1200, Loss 0.19743838906288147
# Starting epoch 24/70, LR = [2]
# Step 1250, Loss 0.18283163011074066
# Starting epoch 25/70, LR = [2]
# Step 1300, Loss 0.19190524518489838
# Starting epoch 26/70, LR = [2]
# Step 1350, Loss 0.1841937005519867
# Step 1400, Loss 0.20446865260601044
# Starting epoch 27/70, LR = [2]
# Step 1450, Loss 0.19043925404548645
# Starting epoch 28/70, LR = [2]
# Step 1500, Loss 0.21781077980995178
# Starting epoch 29/70, LR = [2]
# Step 1550, Loss 0.2014472484588623
# Starting epoch 30/70, LR = [2]
# Step 1600, Loss 0.20239734649658203
# Starting epoch 31/70, LR = [2]
# Step 1650, Loss 0.1869218796491623
# Starting epoch 32/70, LR = [2]
# Step 1700, Loss 0.17450660467147827
# Starting epoch 33/70, LR = [2]
# Step 1750, Loss 0.1979595571756363
# Starting epoch 34/70, LR = [2]
# Step 1800, Loss 0.22814522683620453
# Starting epoch 35/70, LR = [2]
# Step 1850, Loss 0.20328360795974731
# Starting epoch 36/70, LR = [2]
# Step 1900, Loss 0.19130928814411163
# Starting epoch 37/70, LR = [2]
# Step 1950, Loss 0.19071026146411896
# Starting epoch 38/70, LR = [2]
# Step 2000, Loss 0.18499885499477386
# Step 2050, Loss 0.1856914907693863
# Starting epoch 39/70, LR = [2]
# Step 2100, Loss 0.2189536988735199
# Starting epoch 40/70, LR = [2]
# Step 2150, Loss 0.17289631068706512
# Starting epoch 41/70, LR = [2]
# Step 2200, Loss 0.1798419952392578
# Starting epoch 42/70, LR = [2]
# Step 2250, Loss 0.17781753838062286
# Starting epoch 43/70, LR = [2]
# Step 2300, Loss 0.20777840912342072
# Starting epoch 44/70, LR = [2]
# Step 2350, Loss 0.16780985891819
# Starting epoch 45/70, LR = [2]
# Step 2400, Loss 0.17257137596607208
# Starting epoch 46/70, LR = [2]
# Step 2450, Loss 0.20022140443325043
# Starting epoch 47/70, LR = [2]
# Step 2500, Loss 0.20261652767658234
# Starting epoch 48/70, LR = [2]
# Step 2550, Loss 0.1893659234046936
# Starting epoch 49/70, LR = [0.4]
# Step 2600, Loss 0.14315608143806458
# Starting epoch 50/70, LR = [0.4]
# Step 2650, Loss 0.1370536983013153
# Starting epoch 51/70, LR = [0.4]
# Step 2700, Loss 0.1452072411775589
# Step 2750, Loss 0.1396128535270691
# Starting epoch 52/70, LR = [0.4]
# Step 2800, Loss 0.11496274918317795
# Starting epoch 53/70, LR = [0.4]
# Step 2850, Loss 0.11807515472173691
# Starting epoch 54/70, LR = [0.4]
# Step 2900, Loss 0.10608266294002533
# Starting epoch 55/70, LR = [0.4]
# Step 2950, Loss 0.10621446371078491
# Starting epoch 56/70, LR = [0.4]
# Step 3000, Loss 0.1364193856716156
# Starting epoch 57/70, LR = [0.4]
# Step 3050, Loss 0.11304907500743866
# Starting epoch 58/70, LR = [0.4]
# Step 3100, Loss 0.11984042823314667
# Starting epoch 59/70, LR = [0.4]
# Step 3150, Loss 0.15692973136901855
# Starting epoch 60/70, LR = [0.4]
# Step 3200, Loss 0.13110336661338806
# Starting epoch 61/70, LR = [0.4]
# Step 3250, Loss 0.12645940482616425
# Starting epoch 62/70, LR = [0.4]
# Step 3300, Loss 0.11441519111394882
# Starting epoch 63/70, LR = [0.08000000000000002]
# Step 3350, Loss 0.13911472260951996
# Step 3400, Loss 0.1097755953669548
# Starting epoch 64/70, LR = [0.08000000000000002]
# Step 3450, Loss 0.10041047632694244
# Starting epoch 65/70, LR = [0.08000000000000002]
# Step 3500, Loss 0.09894519299268723
# Starting epoch 66/70, LR = [0.08000000000000002]
# Step 3550, Loss 0.10183005034923553
# Starting epoch 67/70, LR = [0.08000000000000002]
# Step 3600, Loss 0.09537728130817413
# Starting epoch 68/70, LR = [0.08000000000000002]
# Step 3650, Loss 0.08307275921106339
# Starting epoch 69/70, LR = [0.08000000000000002]
# Step 3700, Loss 0.09066108614206314
# Starting epoch 70/70, LR = [0.08000000000000002]
# Step 3750, Loss 0.10873773694038391
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Computing Means
# classifing
# Test Accuracy: 0.42233333333333334
# processing batch 7
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Starting epoch 1/70, LR = [2]
# Step 0, Loss 0.2704016864299774
# Step 50, Loss 0.23204226791858673
# Starting epoch 2/70, LR = [2]
# Step 100, Loss 0.20976145565509796
# Starting epoch 3/70, LR = [2]
# Step 150, Loss 0.23036722838878632
# Starting epoch 4/70, LR = [2]
# Step 200, Loss 0.22968000173568726
# Starting epoch 5/70, LR = [2]
# Step 250, Loss 0.24290135502815247
# Starting epoch 6/70, LR = [2]
# Step 300, Loss 0.24223746359348297
# Starting epoch 7/70, LR = [2]
# Step 350, Loss 0.2209068238735199
# Starting epoch 8/70, LR = [2]
# Step 400, Loss 0.2111399620771408
# Starting epoch 9/70, LR = [2]
# Step 450, Loss 0.215815007686615
# Starting epoch 10/70, LR = [2]
# Step 500, Loss 0.2294062376022339
# Starting epoch 11/70, LR = [2]
# Step 550, Loss 0.22023311257362366
# Starting epoch 12/70, LR = [2]
# Step 600, Loss 0.19154639542102814
# Starting epoch 13/70, LR = [2]
# Step 650, Loss 0.23064036667346954
# Step 700, Loss 0.22626543045043945
# Starting epoch 14/70, LR = [2]
# Step 750, Loss 0.21021972596645355
# Starting epoch 15/70, LR = [2]
# Step 800, Loss 0.23851902782917023
# Starting epoch 16/70, LR = [2]
# Step 850, Loss 0.2203795164823532
# Starting epoch 17/70, LR = [2]
# Step 900, Loss 0.21159671247005463
# Starting epoch 18/70, LR = [2]
# Step 950, Loss 0.20060688257217407
# Starting epoch 19/70, LR = [2]
# Step 1000, Loss 0.1988818645477295
# Starting epoch 20/70, LR = [2]
# Step 1050, Loss 0.265849232673645
# Starting epoch 21/70, LR = [2]
# Step 1100, Loss 0.2128831446170807
# Starting epoch 22/70, LR = [2]
# Step 1150, Loss 0.2141537219285965
# Starting epoch 23/70, LR = [2]
# Step 1200, Loss 0.21603736281394958
# Starting epoch 24/70, LR = [2]
# Step 1250, Loss 0.17760421335697174
# Starting epoch 25/70, LR = [2]
# Step 1300, Loss 0.24088358879089355
# Starting epoch 26/70, LR = [2]
# Step 1350, Loss 0.17726369202136993
# Step 1400, Loss 0.1908663660287857
# Starting epoch 27/70, LR = [2]
# Step 1450, Loss 0.2546912729740143
# Starting epoch 28/70, LR = [2]
# Step 1500, Loss 0.22779914736747742
# Starting epoch 29/70, LR = [2]
# Step 1550, Loss 0.2042967677116394
# Starting epoch 30/70, LR = [2]
# Step 1600, Loss 0.2240637093782425
# Starting epoch 31/70, LR = [2]
# Step 1650, Loss 0.2072506844997406
# Starting epoch 32/70, LR = [2]
# Step 1700, Loss 0.21626883745193481
# Starting epoch 33/70, LR = [2]
# Step 1750, Loss 0.20876897871494293
# Starting epoch 34/70, LR = [2]
# Step 1800, Loss 0.189720019698143
# Starting epoch 35/70, LR = [2]
# Step 1850, Loss 0.1990106850862503
# Starting epoch 36/70, LR = [2]
# Step 1900, Loss 0.19647423923015594
# Starting epoch 37/70, LR = [2]
# Step 1950, Loss 0.21071378886699677
# Starting epoch 38/70, LR = [2]
# Step 2000, Loss 0.18308798968791962
# Step 2050, Loss 0.21516257524490356
# Starting epoch 39/70, LR = [2]
# Step 2100, Loss 0.17738907039165497
# Starting epoch 40/70, LR = [2]
# Step 2150, Loss 0.20092232525348663
# Starting epoch 41/70, LR = [2]
# Step 2200, Loss 0.19835124909877777
# Starting epoch 42/70, LR = [2]
# Step 2250, Loss 0.210974782705307
# Starting epoch 43/70, LR = [2]
# Step 2300, Loss 0.17444851994514465
# Starting epoch 44/70, LR = [2]
# Step 2350, Loss 0.21806243062019348
# Starting epoch 45/70, LR = [2]
# Step 2400, Loss 0.21211181581020355
# Starting epoch 46/70, LR = [2]
# Step 2450, Loss 0.20315177738666534
# Starting epoch 47/70, LR = [2]
# Step 2500, Loss 0.20703180134296417
# Starting epoch 48/70, LR = [2]
# Step 2550, Loss 0.2037830352783203
# Starting epoch 49/70, LR = [0.4]
# Step 2600, Loss 0.15298281610012054
# Starting epoch 50/70, LR = [0.4]
# Step 2650, Loss 0.1510404348373413
# Starting epoch 51/70, LR = [0.4]
# Step 2700, Loss 0.1320313960313797
# Step 2750, Loss 0.14902755618095398
# Starting epoch 52/70, LR = [0.4]
# Step 2800, Loss 0.12909674644470215
# Starting epoch 53/70, LR = [0.4]
# Step 2850, Loss 0.17177550494670868
# Starting epoch 54/70, LR = [0.4]
# Step 2900, Loss 0.133286714553833
# Starting epoch 55/70, LR = [0.4]
# Step 2950, Loss 0.11012526601552963
# Starting epoch 56/70, LR = [0.4]
# Step 3000, Loss 0.13384506106376648
# Starting epoch 57/70, LR = [0.4]
# Step 3050, Loss 0.14035455882549286
# Starting epoch 58/70, LR = [0.4]
# Step 3100, Loss 0.1304408758878708
# Starting epoch 59/70, LR = [0.4]
# Step 3150, Loss 0.12097137421369553
# Starting epoch 60/70, LR = [0.4]
# Step 3200, Loss 0.13846443593502045
# Starting epoch 61/70, LR = [0.4]
# Step 3250, Loss 0.11596766114234924
# Starting epoch 62/70, LR = [0.4]
# Step 3300, Loss 0.13256250321865082
# Starting epoch 63/70, LR = [0.08000000000000002]
# Step 3350, Loss 0.13118062913417816
# Step 3400, Loss 0.11350142955780029
# Starting epoch 64/70, LR = [0.08000000000000002]
# Step 3450, Loss 0.11806829273700714
# Starting epoch 65/70, LR = [0.08000000000000002]
# Step 3500, Loss 0.10347915440797806
# Starting epoch 66/70, LR = [0.08000000000000002]
# Step 3550, Loss 0.09211237728595734
# Starting epoch 67/70, LR = [0.08000000000000002]
# Step 3600, Loss 0.11003187298774719
# Starting epoch 68/70, LR = [0.08000000000000002]
# Step 3650, Loss 0.12785792350769043
# Starting epoch 69/70, LR = [0.08000000000000002]
# Step 3700, Loss 0.12947705388069153
# Starting epoch 70/70, LR = [0.08000000000000002]
# Step 3750, Loss 0.11402668058872223
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Computing Means
# classifing
# Test Accuracy: 0.37085714285714283
# processing batch 8
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-bd44e41b4b4b> in <module>()
#      12   lbls, new_labels = make_data_labels(lbls) # take 10 new classes
#      13   for label in new_labels:
# ---> 14     train_dataset = CIFAR100_tError(DATA_DIR, train=True, transform=eval_transform, download=True)
#      15     train_dataset.increment([label],[t])
#      16     test_dataset.increment([label],[t])
#
# /content/Project_MLDL/CIFAR100_tError.py in __init__(self, root, train, transform, download, lbls)
#      32     """
#      33     flag = train
# ---> 34     self.prova = CIFAR100(root, train=flag, download=download)
#      35     self.transform = transform
#      36     self.data = []
#
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/cifar.py in __init__(self, root, train, transform, target_transform, download)
#      58             self.download()
#      59
# ---> 60         if not self._check_integrity():
#      61             raise RuntimeError('Dataset not found or corrupted.' +
#      62                                ' You can use download=True to download it')
#
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/cifar.py in _check_integrity(self)
#     126             filename, md5 = fentry[0], fentry[1]
#     127             fpath = os.path.join(root, self.base_folder, filename)
# --> 128             if not check_integrity(fpath, md5):
#     129                 return False
#     130         return True
#
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/utils.py in check_integrity(fpath, md5)
#      40     if md5 is None:
#      41         return True
# ---> 42     return check_md5(fpath, md5)
#      43
#      44
#
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/utils.py in check_md5(fpath, md5, **kwargs)
#      32
#      33 def check_md5(fpath, md5, **kwargs):
# ---> 34     return md5 == calculate_md5(fpath, **kwargs)
#      35
#      36
#
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/utils.py in calculate_md5(fpath, chunk_size)
#      27     with open(fpath, 'rb') as f:
#      28         for chunk in iter(lambda: f.read(chunk_size), b''):
# ---> 29             md5.update(chunk)
#      30     return md5.hexdigest()
#      31
#
# KeyboardInterrupt:

# %% [markdown]
# **Define plot function**
#
# ---

# %%
def accuracy_plot(accuracies):
  ### FOR MEAN STD PLOT https://stackoverflow.com/questions/22481854/plot-mean-and-standard-deviation
  from scipy import interpolate

  tck,u     = interpolate.splprep( [[i*10 for i in range(1,len(accuracies)+1)],accuracies] ,s = 0 )
  xnew,ynew = interpolate.splev( np.linspace( 0, 1, 100 ), tck,der = 0)

  fig, ax = plt.subplots(figsize=(15,14), facecolor='white')

  plt.rc('font', size=20)
  plt.plot( [i*10 for i in range(1,len(accuracies)+1)],accuracies,'.' , xnew ,ynew, label = "accuracy", c='orange' )
  ax.set_ylabel("Accuracy")
  ax.set_xlabel("Classes")
  ax.minorticks_on()
  plt.title("Accuracies obtained with Icarl")
  plt.yticks(np.arange(0, 1.1, .1))
  plt.xticks(np.arange(0, 110, 10))
  plt.grid(axis='y',which='major', linestyle='-', linewidth='0.5', color='black') 
  plt.grid(axis='y',which='minor', linestyle=':', linewidth='0.5', color='grey')
  for in_i, in_j in zip([i*10 for i in range(1,len(accuracies)+1)], accuracies):  # Plot also the value of the point close to it
          ax.annotate(str(round(in_j, 3)), xy=(in_i, in_j))

  plt.savefig('test.png', format='png', dpi=300)
  plt.show()

# %% [markdown]
# *Print & Plot*

# %%
print(accuracies)

accuracy_plot(accuracies)
