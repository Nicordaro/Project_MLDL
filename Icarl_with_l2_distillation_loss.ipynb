# %% [markdown]
# <a href="https://colab.research.google.com/github/Nicordaro/Project_MLDL/blob/master/Icarl_with_l2_distillation_loss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Cloning files needed*

# %%
import os
# Clone github repository with data
# if os.path.isdir('./Project_MLDL'):
# !rm -rf Project_MLDL
if not os.path.isdir('./CIFAR100_tError'):
  # !git clone https://github.com/Nicordaro/Project_MLDL
# Out:
# Cloning into 'Project_MLDL'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (146/146), done.
# remote: Total 366 (delta 83), reused 0 (delta 0), pack-reused 220
# Receiving objects: 100% (366/366), 1.22 MiB | 1.40 MiB/s, done.
# Resolving deltas: 100% (190/190), done.

# %% [markdown]
# **Imports**
#
# ---

# %%
import logging
import matplotlib.pyplot as plt
import numpy as np
import random
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import time
import gc



from PIL import Image
from Project_MLDL.CIFAR100_tError import CIFAR100_tError
from Project_MLDL.model_finetuning import ResNet18
from torch.utils.data import Subset, DataLoader
from torch.backends import cudnn
from torchvision import transforms
from torchvision.models import resnet18
from torchvision.models import resnet34
from tqdm import tqdm

# Garbage collector
gc.enable()

# %% [markdown]
# **Arguments**
#
# ---

# %%
DEVICE = 'cuda' # 'cuda' or 'cpu'

# Init at 10 because first train is on 10 classes
NUM_CLASSES = 10

# Used for the pseudorandom shuffle of the split
SEED = 12

BATCH_SIZE = 128     # Higher batch sizes allows for larger learning rates. An empirical heuristic suggests that, when changing
                     # the batch size, learning rate should change by the same factor to have comparable results

LR = 2         # The initial Learning Rate
MOMENTUM = 0.9       # Hyperparameter for SGD, keep this at 0.9 when using SGD
WEIGHT_DECAY = 1e-5  # Regularization, you can keep this at the default

NUM_EPOCHS = 70     # Total number of training epochs (iterations over dataset)
MILESTONES = [48, 62]  # How many epochs before decreasing learning rate (if using a step-down policy)
GAMMA = 0.2          # Multiplicative factor for learning rate step-down

LOG_FREQUENCY = 50

# %% [markdown]
# **Transformations definition**
#
# ---

# %%
# Define transforms for training phase
train_transform = transforms.Compose([transforms.RandomHorizontalFlip(), # Randomly flip the image with probability of 0.5
                                      transforms.Pad(4), # Add padding
                                      transforms.RandomCrop(32),# Crops a random squares of the image
                                      transforms.ToTensor(), # Turn PIL Image to torch.Tensor
                                      transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))  # https://gist.github.com/weiaicunzai/e623931921efefd4c331622c344d8151
])
# Define transforms for the evaluation phase
eval_transform = transforms.Compose([
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))                                 
])
eval_transform = transforms.Compose([
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))                                 
])
exemplar_transform = transforms.Compose([transforms.RandomHorizontalFlip(), # Randomly flip the image with probability of 0.5
                                      transforms.Pad(4), # Add padding
                                      transforms.RandomCrop(32),# Crops a random squares of the image
                                      transforms.ToTensor() # Turn PIL Image to torch.Tensor
])

# %% [markdown]
# *New label function*

# %%
DATA_DIR = './CIFAR100'

lbls = [i for i in range(0,100)]  #Array of classes integer-encoded (?)
random.seed(SEED)
random.shuffle(lbls)

def make_data_labels(lbls):       #After shuffle, take first 10 classes, and remove the first 10 from the list passed as argument
    new_labels=[]
    for el in lbls[:10]:
        new_labels.append(el)
    lbls = lbls[10:]

    return lbls, new_labels

# %%
from torch.utils.data import Dataset
"""
Take 2 datasets with different properties and combine them
"""
class joint_dataset(Dataset):
    
    def __init__(self,d1,d2):
        self.l1 = len(d1)
        self.l2 = len(d2)
        self.d1 = d1
        self.d2 = d2
    def __getitem__(self,index):
        if index>=self.l1:
            image,label = self.d2[index-self.l1]
            image = exemplar_transform(image)
            return image,label
        else:
            image,label = self.d1[index]
            return image,label
    def __len__(self):
        return (self.l1 + self.l2)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import copy
from torch.autograd import Variable

class iCaRL(nn.Module):
  def __init__(self):
    super(iCaRL, self).__init__()

    # CNN with 100 neurons in the last layer 
    self.net = ResNet18()
    self.net.linear = nn.Linear(512, 100)
    
    # Resnet with last layer empty and used as a feature extractor
    self.fe = ResNet18()
    self.fe.linear = nn.Sequential()
    
    # Classification and Distillation losses
    self.cls_loss = nn.BCEWithLogitsLoss(reduction='none')
    self.dist_loss = nn.MSELoss(reduction='none')
    
    self.exemplar_sets=[] # List of exemplar sets, one for each class
    self.exemplars_means=[] # List of exemplar means, one for each exemplar set

  def classify(self, x):

    torch.no_grad()
    torch.cuda.empty_cache()
    
    feature_extractor = self.fe.to(DEVICE)
    feature_extractor.train(False)

    size = x.size(0) # Take batch size

    means = torch.cat(self.exemplar_means,dim=0) # Tensor of means (num_classes,num_features)
    means = torch.stack([means]*size) # (batch_size,num_classes,num_features)
    means = means.transpose(1, 2) # (batch_size,num_features,num_classes)
    
    feature_x = feature_extractor(x) # (batch_size, num_features)
    
    # Normalize features
    features_normalized = []
    for x in feature_x:
        x.data = x.data / x.data.norm()
        features_normalized.append(x)   
    feature_x = torch.stack(features_normalized,dim=0)

    feature_x = feature_x.unsqueeze(2) # (batch_size, feature_size, 1)
    feature_x = feature_x.expand_as(means) # (batch_size, feature_size, n_classes)

    # find the nearest prototype
    means = means.to(DEVICE)
    labels = torch.argmin((feature_x - means).pow(2).sum(1),dim=1)
    
    #clean memory
    del feature_x
    del means
    del x
    del feature_extractor
    torch.no_grad()
    torch.cuda.empty_cache()
    gc.collect()
    
    return labels

  def compute_means(self):
    torch.no_grad()  
    torch.cuda.empty_cache()

    # Given the exemplar sets, compute the means

    exemplar_means = []
    feature_extractor = self.fe.to(DEVICE)
    feature_extractor.train(False)
    with torch.no_grad():
      for Py in self.exemplar_sets:
        features=[]
        for p in Py:
          p = p.to(DEVICE)
          feature = feature_extractor(p)
          features.append(feature)
          #Clean Memory
          del p
          del feature
          torch.no_grad()
          torch.cuda.empty_cache()

        features = torch.stack(features) # (num_exemplars,num_features)
        mu_y = features.mean(0) 
        mu_y.data = mu_y.data / mu_y.data.norm() # Normalize
        mu_y = mu_y.to('cpu')
        exemplar_means.append(mu_y)
        del features
        del mu_y
        torch.no_grad()  
        torch.cuda.empty_cache()

    self.exemplar_means = exemplar_means

    #Clean Memory
    del exemplar_means
    del feature_extractor
    torch.no_grad()
    torch.cuda.empty_cache()

  def reduce_exemplar_sets(self,m):
    for y, P_y in enumerate(self.exemplar_sets):
      m = int(m)
      self.exemplar_sets[y] = P_y[:m] # keep only the first m exemplars
  
  def construct_exemplar_set(self,X,m):
    
    # X dataset containing all elements of class y

    torch.no_grad()
    torch.cuda.empty_cache()
    gc.collect()

    feature_extractor = self.fe.to(DEVICE)
    feature_extractor.train(False)
    loader = DataLoader(X,batch_size=BATCH_SIZE,shuffle=True,drop_last=False,num_workers = 4) # create dataloader

    features = []
    
    for images,labels in loader:
      images = images.to(DEVICE)
      labels = labels.to(DEVICE)
      feature = feature_extractor(images)
      features.append(feature)
      del images
      del labels
      del feature
        
    features_stacked = torch.cat(features) # (num_elements,num_features)
    mean = features_stacked.mean(0) #(num_features)
    mean = torch.stack([mean]*features_stacked.size()[0])  # (num_elements,num_features)
    torch.cuda.empty_cache()
    P = [] # exemplar set
    extracted_features = []

    summa = torch.zeros(1,features_stacked.size()[1]).to(DEVICE) #(1,num_features)
    
    for k in range(1,int(m+1)):
      s = torch.cat([summa]*features_stacked.size()[0]) #(num_elements,num_features)
      index = torch.argmin((mean-(1/k)*(features_stacked+s)).pow(2).sum(1),dim=0)
      pk = X[index.item()][0].unsqueeze(dim=0) # take the image, leave the label
      P.append(pk)
      phipk =  feature_extractor(pk.to(DEVICE))
      summa = summa + phipk # update sum of features
      del pk 
   
    #Clear Memory
    del summa
    del features
    del features_stacked
    del mean
    del s
    del feature_extractor
    del loader
    torch.cuda.empty_cache()
    self.exemplar_sets.append(P)
    

  def update_representation(self,X): 
    
    trans = transforms.ToPILImage()
    #Take exemplars
    exemplars_dataset = []
    for i in range(0,len(self.exemplar_sets)):
        for exemplar in self.exemplar_sets[i]:
            exemplar = trans(exemplar.squeeze()).convert("RGB")
            exemplars_dataset.append((exemplar,i)) #append image already transformed with label = index

    D = joint_dataset(X,exemplars_dataset) # Build the dataset 
   
    net = self.net

    #optimizer
    optimizer = optim.SGD(net.parameters(), lr=2, weight_decay=1e-5, momentum=0.9)

    # Scheduler
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=MILESTONES, gamma=GAMMA, last_epoch=-1)

    criterion = self.cls_loss
    criterion2 = self.dist_loss

    cudnn.benchmark # Calling this optimizes runtime

    current_step = 0
    net = net.to(DEVICE)
    
    # Create Dataloader 
    loader = DataLoader(D, batch_size=BATCH_SIZE, shuffle=True, num_workers=4, drop_last=True)
    
    if len(self.exemplar_sets)>1:
        old = copy.deepcopy(net) #copy network before training

    old_feature_extractor = self.fe.to(DEVICE)

    #Training
    for epoch in range(NUM_EPOCHS):
      print('Starting epoch {}/{}, LR = {}'.format(epoch+1, NUM_EPOCHS, scheduler.get_last_lr()))

        # Iterate over the dataset
      for images, labels in loader:
          # Bring data over the device of choice
          images = images.to(DEVICE)
          labels = labels.to(DEVICE)
          net.train()
        
          optimizer.zero_grad() # Zero-ing the gradients

          # Forward pass to the network
          outputs = net(images)

          # One hot encoding labels for binary cross-entropy loss
          labels_onehot = nn.functional.one_hot(labels,100).type_as(outputs)
                    
          # Compute Loss
          if len(self.exemplar_sets) == 0:
            loss = criterion(outputs, labels_onehot).mean()
          else:
            class_loss = criterion(outputs[:,len(self.exemplar_sets):], labels_onehot[:,len(self.exemplar_sets):])
            new_feature_extractor = copy.deepcopy(net)
            new_feature_extractor.linear = nn.Sequential()
            new_feature_extractor = new_feature_extractor.to(DEVICE)
            distillation = criterion2(old_feature_extractor(images), new_feature_extractor(images))
            loss = torch.cat([class_loss, distillation], dim=1).mean()
            # loss = class_loss + distillation

          if current_step % LOG_FREQUENCY == 0:
              print('Step {}, Loss {}'.format(current_step, loss.item()))

          loss.backward()  # backward pass: computes gradients
          optimizer.step()  # update weights based on accumulated gradients
          current_step += 1
        
      scheduler.step()
    
    # Save the trained network and update features extractor
    self.net = copy.deepcopy(net)
    self.fe = copy.deepcopy(net)
    self.fe.linear = nn.Sequential()
    del net
    torch.no_grad()
    torch.cuda.empty_cache()

# %% [markdown]
# ** Incremental Train **

# %%
net = iCaRL()
K = 2000 # Memory Size
t = 0 # Number of classes
accuracies = [] # List of results 
test_dataset = CIFAR100_tError(DATA_DIR, train=False, transform=eval_transform, download=True)

for i in range(0,10): # batches of 10
  print(f"processing batch {i+1}")
  #Create Datasets
  train_datasets = []
  train_dataset_big = CIFAR100_tError(DATA_DIR, train=True, transform=train_transform, download=True)
  lbls, new_labels = make_data_labels(lbls) # take 10 new classes
  for label in new_labels:
    train_dataset = CIFAR100_tError(DATA_DIR, train=True, transform=eval_transform, download=True)
    train_dataset.increment([label],[t])
    test_dataset.increment([label],[t])
    train_dataset_big.increment([label],[t])
    train_datasets.append(train_dataset) # List of training examples in per class sets
    t += 1
  test_dataloader = DataLoader(test_dataset,batch_size=BATCH_SIZE,shuffle=True,num_workers=4)
  net.update_representation(train_dataset_big)
  m = K/t #numbers of exemplars per class
  net.reduce_exemplar_sets(m)
  for X in train_datasets:
    print("Construct Exemplar")
    net.construct_exemplar_set(X,m) #new exemplar sets
    torch.no_grad()
    torch.cuda.empty_cache()
    gc.collect()
  # Test on Test set
  running_corrects = 0
  print("Computing Means")
  net.compute_means()
  print("classifing")
  for images,labels in test_dataloader:
    images = images.to(DEVICE)
    labels = labels.to(DEVICE)
    preds = net.classify(images)
    running_corrects += torch.sum(preds == labels.data).data.item()
    accuracy = running_corrects / float(len(test_dataset))
    del images
    del labels
    del preds
    torch.no_grad()
    torch.cuda.empty_cache()
    gc.collect()
  accuracies.append(accuracy)
  print(f"Test Accuracy: {accuracy}")
# Out:
# Files already downloaded and verified
# processing batch 1
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Starting epoch 1/70, LR = [2]
# Step 0, Loss 0.702673077583313
# Starting epoch 2/70, LR = [2]
# Step 50, Loss 0.023818476125597954
# Starting epoch 3/70, LR = [2]
# Step 100, Loss 0.021192261949181557
# Starting epoch 4/70, LR = [2]
# Step 150, Loss 0.02115391381084919
# Starting epoch 5/70, LR = [2]
# Starting epoch 6/70, LR = [2]
# Step 200, Loss 0.019877241924405098
# Starting epoch 7/70, LR = [2]
# Step 250, Loss 0.01916550286114216
# Starting epoch 8/70, LR = [2]
# Step 300, Loss 0.01624303311109543
# Starting epoch 9/70, LR = [2]
# Step 350, Loss 0.01915043778717518
# Starting epoch 10/70, LR = [2]
# Starting epoch 11/70, LR = [2]
# Step 400, Loss 0.012676353566348553
# Starting epoch 12/70, LR = [2]
# Step 450, Loss 0.01317469123750925
# Starting epoch 13/70, LR = [2]
# Step 500, Loss 0.014874501153826714
# Starting epoch 14/70, LR = [2]
# Starting epoch 15/70, LR = [2]
# Step 550, Loss 0.013884589076042175
# Starting epoch 16/70, LR = [2]
# Step 600, Loss 0.011447068303823471
# Starting epoch 17/70, LR = [2]
# Step 650, Loss 0.012331461533904076
# Starting epoch 18/70, LR = [2]
# Step 700, Loss 0.011667477898299694
# Starting epoch 19/70, LR = [2]
# Starting epoch 20/70, LR = [2]
# Step 750, Loss 0.00879290048032999
# Starting epoch 21/70, LR = [2]
# Step 800, Loss 0.010943657718598843
# Starting epoch 22/70, LR = [2]
# Step 850, Loss 0.009542403742671013
# Starting epoch 23/70, LR = [2]
# Starting epoch 24/70, LR = [2]
# Step 900, Loss 0.008531986735761166
# Starting epoch 25/70, LR = [2]
# Step 950, Loss 0.006200465373694897
# Starting epoch 26/70, LR = [2]
# Step 1000, Loss 0.010683396831154823
# Starting epoch 27/70, LR = [2]
# Step 1050, Loss 0.006816835142672062
# Starting epoch 28/70, LR = [2]
# Starting epoch 29/70, LR = [2]
# Step 1100, Loss 0.0071507589891552925
# Starting epoch 30/70, LR = [2]
# Step 1150, Loss 0.005938701331615448
# Starting epoch 31/70, LR = [2]
# Step 1200, Loss 0.007405327167361975
# Starting epoch 32/70, LR = [2]
# Starting epoch 33/70, LR = [2]
# Step 1250, Loss 0.006928052753210068
# Starting epoch 34/70, LR = [2]
# Step 1300, Loss 0.0038562582340091467
# Starting epoch 35/70, LR = [2]
# Step 1350, Loss 0.0038473522290587425
# Starting epoch 36/70, LR = [2]
# Step 1400, Loss 0.006197395268827677
# Starting epoch 37/70, LR = [2]
# Starting epoch 38/70, LR = [2]
# Step 1450, Loss 0.004759305156767368
# Starting epoch 39/70, LR = [2]
# Step 1500, Loss 0.006622957531362772
# Starting epoch 40/70, LR = [2]
# Step 1550, Loss 0.007057283539324999
# Starting epoch 41/70, LR = [2]
# Starting epoch 42/70, LR = [2]
# Step 1600, Loss 0.005330711603164673
# Starting epoch 43/70, LR = [2]
# Step 1650, Loss 0.0040287128649652
# Starting epoch 44/70, LR = [2]
# Step 1700, Loss 0.005647904705256224
# Starting epoch 45/70, LR = [2]
# Step 1750, Loss 0.0036980940494686365
# Starting epoch 46/70, LR = [2]
# Starting epoch 47/70, LR = [2]
# Step 1800, Loss 0.0037429460790008307
# Starting epoch 48/70, LR = [2]
# Step 1850, Loss 0.0038908892311155796
# Starting epoch 49/70, LR = [0.4]
# Step 1900, Loss 0.0011571455979719758
# Starting epoch 50/70, LR = [0.4]
# Starting epoch 51/70, LR = [0.4]
# Step 1950, Loss 0.001564307021908462
# Starting epoch 52/70, LR = [0.4]
# Step 2000, Loss 0.0005417024367488921
# Starting epoch 53/70, LR = [0.4]
# Step 2050, Loss 0.0012762142578139901
# Starting epoch 54/70, LR = [0.4]
# Step 2100, Loss 0.0006961820181459188
# Starting epoch 55/70, LR = [0.4]
# Starting epoch 56/70, LR = [0.4]
# Step 2150, Loss 0.0009760856628417969
# Starting epoch 57/70, LR = [0.4]
# Step 2200, Loss 0.00044677554978989065
# Starting epoch 58/70, LR = [0.4]
# Step 2250, Loss 0.00036626210203394294
# Starting epoch 59/70, LR = [0.4]
# Step 2300, Loss 0.0005094276275485754
# Starting epoch 60/70, LR = [0.4]
# Starting epoch 61/70, LR = [0.4]
# Step 2350, Loss 0.00019800856534857303
# Starting epoch 62/70, LR = [0.4]
# Step 2400, Loss 0.00029082142282277346
# Starting epoch 63/70, LR = [0.08000000000000002]
# Step 2450, Loss 0.00032381428172811866
# Starting epoch 64/70, LR = [0.08000000000000002]
# Starting epoch 65/70, LR = [0.08000000000000002]
# Step 2500, Loss 0.00013462529750540853
# Starting epoch 66/70, LR = [0.08000000000000002]
# Step 2550, Loss 0.00021514156833291054
# Starting epoch 67/70, LR = [0.08000000000000002]
# Step 2600, Loss 0.00019438521121628582
# Starting epoch 68/70, LR = [0.08000000000000002]
# Step 2650, Loss 0.0001558412186568603
# Starting epoch 69/70, LR = [0.08000000000000002]
# Starting epoch 70/70, LR = [0.08000000000000002]
# Step 2700, Loss 0.00023735336435493082
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Computing Means
# classifing
# Test Accuracy: 0.851
# processing batch 2
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Starting epoch 1/70, LR = [2]
# Step 0, Loss 0.18712738156318665
# Step 50, Loss 0.4119991362094879
# Starting epoch 2/70, LR = [2]
# Step 100, Loss 0.412676602602005
# Starting epoch 3/70, LR = [2]
# Step 150, Loss 0.3829866647720337
# Starting epoch 4/70, LR = [2]
# Step 200, Loss 0.39425748586654663
# Starting epoch 5/70, LR = [2]
# Step 250, Loss 0.407012939453125
# Starting epoch 6/70, LR = [2]
# Step 300, Loss 0.401153564453125
# Starting epoch 7/70, LR = [2]
# Step 350, Loss 0.4163508117198944
# Starting epoch 8/70, LR = [2]
# Step 400, Loss 0.39390021562576294
# Starting epoch 9/70, LR = [2]
# Step 450, Loss 0.4106025695800781
# Starting epoch 10/70, LR = [2]
# Step 500, Loss 0.3850077986717224
# Starting epoch 11/70, LR = [2]
# Step 550, Loss 0.43079957365989685
# Starting epoch 12/70, LR = [2]
# Step 600, Loss 0.41178128123283386
# Starting epoch 13/70, LR = [2]
# Step 650, Loss 0.42298370599746704
# Step 700, Loss 0.40699705481529236
# Starting epoch 14/70, LR = [2]
# Step 750, Loss 0.3995717763900757
# Starting epoch 15/70, LR = [2]
# Step 800, Loss 0.40614938735961914
# Starting epoch 16/70, LR = [2]
# Step 850, Loss 0.39267516136169434
# Starting epoch 17/70, LR = [2]
# Step 900, Loss 0.42298412322998047
# Starting epoch 18/70, LR = [2]
# Step 950, Loss 0.40324097871780396
# Starting epoch 19/70, LR = [2]
# Step 1000, Loss 0.44364821910858154
# Starting epoch 20/70, LR = [2]
# Step 1050, Loss 0.4050285518169403
# Starting epoch 21/70, LR = [2]
# Step 1100, Loss 0.4028744399547577
# Starting epoch 22/70, LR = [2]
# Step 1150, Loss 0.4284279942512512
# Starting epoch 23/70, LR = [2]
# Step 1200, Loss 0.4075167179107666
# Starting epoch 24/70, LR = [2]
# Step 1250, Loss 0.4321621060371399
# Starting epoch 25/70, LR = [2]
# Step 1300, Loss 0.4116431176662445
# Starting epoch 26/70, LR = [2]
# Step 1350, Loss 0.41578781604766846
# Step 1400, Loss 0.40755900740623474
# Starting epoch 27/70, LR = [2]
# Step 1450, Loss 0.4124208688735962
# Starting epoch 28/70, LR = [2]
# Step 1500, Loss 0.4290224313735962
# Starting epoch 29/70, LR = [2]
# Step 1550, Loss 0.42702731490135193
# Starting epoch 30/70, LR = [2]
# Step 1600, Loss 0.401215523481369
# Starting epoch 31/70, LR = [2]
# Step 1650, Loss 0.40917205810546875
# Starting epoch 32/70, LR = [2]
# Step 1700, Loss 0.41408687829971313
# Starting epoch 33/70, LR = [2]
# Step 1750, Loss 0.4185793995857239
# Starting epoch 34/70, LR = [2]
# Step 1800, Loss 0.4010123312473297
# Starting epoch 35/70, LR = [2]
# Step 1850, Loss 0.41077739000320435
# Starting epoch 36/70, LR = [2]
# Step 1900, Loss 0.41383400559425354
# Starting epoch 37/70, LR = [2]
# Step 1950, Loss 0.4082203209400177
# Starting epoch 38/70, LR = [2]
# Step 2000, Loss 0.41484442353248596
# Step 2050, Loss 0.39906230568885803
# Starting epoch 39/70, LR = [2]
# Step 2100, Loss 0.4198887050151825
# Starting epoch 40/70, LR = [2]
# Step 2150, Loss 0.40449079871177673
# Starting epoch 41/70, LR = [2]
# Step 2200, Loss 0.3865436315536499
# Starting epoch 42/70, LR = [2]
# Step 2250, Loss 0.405985563993454
# Starting epoch 43/70, LR = [2]
# Step 2300, Loss 0.386854350566864
# Starting epoch 44/70, LR = [2]
# Step 2350, Loss 0.4066522717475891
# Starting epoch 45/70, LR = [2]
# Step 2400, Loss 0.39166364073753357
# Starting epoch 46/70, LR = [2]
# Step 2450, Loss 0.3733407258987427
# Starting epoch 47/70, LR = [2]
# Step 2500, Loss 0.3781713545322418
# Starting epoch 48/70, LR = [2]
# Step 2550, Loss 0.3874126374721527
# Starting epoch 49/70, LR = [0.4]
# Step 2600, Loss 0.39304277300834656
# Starting epoch 50/70, LR = [0.4]
# Step 2650, Loss 0.40864434838294983
# Starting epoch 51/70, LR = [0.4]
# Step 2700, Loss 0.40267840027809143
# Step 2750, Loss 0.40677905082702637
# Starting epoch 52/70, LR = [0.4]
# Step 2800, Loss 0.37714868783950806
# Starting epoch 53/70, LR = [0.4]
# Step 2850, Loss 0.3908716142177582
# Starting epoch 54/70, LR = [0.4]
# Step 2900, Loss 0.3886580467224121
# Starting epoch 55/70, LR = [0.4]
# Step 2950, Loss 0.38613206148147583
# Starting epoch 56/70, LR = [0.4]
# Step 3000, Loss 0.3944629728794098
# Starting epoch 57/70, LR = [0.4]
# Step 3050, Loss 0.3851574659347534
# Starting epoch 58/70, LR = [0.4]
# Step 3100, Loss 0.38511204719543457
# Starting epoch 59/70, LR = [0.4]
# Step 3150, Loss 0.39964166283607483
# Starting epoch 60/70, LR = [0.4]
# Step 3200, Loss 0.4050406813621521
# Starting epoch 61/70, LR = [0.4]
# Step 3250, Loss 0.38945522904396057
# Starting epoch 62/70, LR = [0.4]
# Step 3300, Loss 0.3935176730155945
# Starting epoch 63/70, LR = [0.08000000000000002]
# Step 3350, Loss 0.38386619091033936
# Step 3400, Loss 0.4026641845703125
# Starting epoch 64/70, LR = [0.08000000000000002]
# Step 3450, Loss 0.3973921239376068
# Starting epoch 65/70, LR = [0.08000000000000002]
# Step 3500, Loss 0.3912413716316223
# Starting epoch 66/70, LR = [0.08000000000000002]
# Step 3550, Loss 0.39067134261131287
# Starting epoch 67/70, LR = [0.08000000000000002]
# Step 3600, Loss 0.37948402762413025
# Starting epoch 68/70, LR = [0.08000000000000002]
# Step 3650, Loss 0.39035478234291077
# Starting epoch 69/70, LR = [0.08000000000000002]
# Step 3700, Loss 0.41467854380607605
# Starting epoch 70/70, LR = [0.08000000000000002]
# Step 3750, Loss 0.401438444852829
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Construct Exemplar
# Computing Means
# classifing
# Test Accuracy: 0.525
# processing batch 3
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Starting epoch 1/70, LR = [2]
# Step 0, Loss 0.10646592080593109
# Step 50, Loss 0.1685987412929535
# Starting epoch 2/70, LR = [2]
# Step 100, Loss 0.1887916922569275
# Starting epoch 3/70, LR = [2]
# Step 150, Loss 0.20503804087638855
# Starting epoch 4/70, LR = [2]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-2a84cf3b5993> in <module>()
#      19     t += 1
#      20   test_dataloader = DataLoader(test_dataset,batch_size=BATCH_SIZE,shuffle=True,num_workers=4)
# ---> 21   net.update_representation(train_dataset_big)
#      22   m = K/t #numbers of exemplars per class
#      23   net.reduce_exemplar_sets(m)
#
# <ipython-input-7-2c0f3becbe66> in update_representation(self, X)
#     236
#     237           loss.backward()  # backward pass: computes gradients
# --> 238           optimizer.step()  # update weights based on accumulated gradients
#     239           current_step += 1
#     240
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py in wrapper(*args, **kwargs)
#      65                 instance._step_count += 1
#      66                 wrapped = func.__get__(instance, cls)
# ---> 67                 return wrapped(*args, **kwargs)
#      68
#      69             # Note that the returned function here is no longer a bound method,
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      13         def decorate_context(*args, **kwargs):
#      14             with self:
# ---> 15                 return func(*args, **kwargs)
#      16         return decorate_context
#      17
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/sgd.py in step(self, closure)
#     110                         d_p = buf
#     111
# --> 112                 p.add_(d_p, alpha=-group['lr'])
#     113
#     114         return loss
#
# KeyboardInterrupt:

# %% [markdown]
# **Define plot function**
#
# ---

# %%
def accuracy_plot(accuracies):
  ### FOR MEAN STD PLOT https://stackoverflow.com/questions/22481854/plot-mean-and-standard-deviation
  from scipy import interpolate

  tck,u     = interpolate.splprep( [[i*10 for i in range(1,len(accuracies)+1)],accuracies] ,s = 0 )
  xnew,ynew = interpolate.splev( np.linspace( 0, 1, 100 ), tck,der = 0)

  fig, ax = plt.subplots(figsize=(15,14), facecolor='white')

  plt.rc('font', size=20)
  plt.plot( [i*10 for i in range(1,len(accuracies)+1)],accuracies,'.' , xnew ,ynew, label = "accuracy", c='orange' )
  ax.set_ylabel("Accuracy")
  ax.set_xlabel("Classes")
  ax.minorticks_on()
  plt.title("Accuracies obtained with Icarl")
  plt.yticks(np.arange(0, 1.1, .1))
  plt.xticks(np.arange(0, 110, 10))
  plt.grid(axis='y',which='major', linestyle='-', linewidth='0.5', color='black') 
  plt.grid(axis='y',which='minor', linestyle=':', linewidth='0.5', color='grey')
  for in_i, in_j in zip([i*10 for i in range(1,len(accuracies)+1)], accuracies):  # Plot also the value of the point close to it
          ax.annotate(str(round(in_j, 3)), xy=(in_i, in_j))

  plt.savefig('test.png', format='png', dpi=300)
  plt.show()

# %% [markdown]
# *Print & Plot*

# %%
print(accuracies)

accuracy_plot(accuracies)
